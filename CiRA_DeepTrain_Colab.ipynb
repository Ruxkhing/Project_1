# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruxkhing/Project_1/blob/main/CiRA_DeepTrain_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import subprocess
ret = subprocess.call(['bash', '-c', 'wget -O  cira_deeptrain_colab.py https://raw.githubusercontent.com/CiRA-AMI/cira-colab-trainer/main/cira_deeptrain_colab.py'])

# %%
# %run cira_deeptrain_colab.py
# Out:
# CiRA Colab Trainer install complete
# HTML(value='\n    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-…
# HTML(value='\n<style>\nbody {\n  margin: 0;\n  padding: 0;\n}\n.widget-box .widget-label {\n  width: 100px;\n}…
# HTML(value="\n    <div class='flex items-end gap-4 mb-1'>\n      <img src='https://raw.githubusercontent.com/C…
# ...
